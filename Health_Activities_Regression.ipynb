# %% [markdown]
# # Question/need:

# %% [markdown]
# The low use of public transportations, and hot weather have led people in Saudi Arabia to adopt a sedentary lifestyle. Moreover, Diabetes have risen over the past few years to reach unprecendent level of 1 of 4 Saudi people have either type I or Type II diabetes.
#
# Goverment have initated multiple programs to encurage people to excercise through educational campaigns, and public walking areas. Nevertheless, Using mobile phone health data (Step count) to predict public activities will be benefecial in campaigns timing and provide insight on contributing factors for high level of activities.

# %% [markdown]
# In this project, we will build regression models to predict peoples daily activities using multiple features
# - Weekday
# - Weather temperature.
# - Weather status (Rain, dust)
# - Hijry calendar (Ramadan, days of special events)
# - School calendar (School days, Exams, Vacation)

# %% [markdown]
# ### Use Cases:
# - Health Campaign timing.
# - Sport competition (Marathon, walking events)
# - Food truck placement around parks and walking courses.

# %% [markdown]
# # Data Description:
# The main activity data will be exported from mobile phone which contain step counts, speed for over 3 years.
# Raw data contain records of irregular intervals that will be aggregated to a daily value.
#
# Features will be scraped from web
# - School calendar.
# - Weather.
# - Hijry Calendar.

# %% [markdown]
# # Tools
# - Python
# - SQL Database
# - AutoML
# - BI Dashboard for exploration
